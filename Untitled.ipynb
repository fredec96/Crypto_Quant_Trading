# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
all_coins = pd.read_csv("Bitcoin_Data.csv")

# %%
all_coins
# Out:
#             date   symbol          open          high       low         close  \
# 0     2022-08-04  BTC/USD  22813.213072  23006.000000  22792.00  22969.000000
# 1     2022-08-03  BTC/USD  22982.000000  23634.097482  22680.00  22813.873707
# 2     2022-08-02  BTC/USD  23256.000000  23466.000000  22676.00  22986.000000
# 3     2022-08-01  BTC/USD  23291.000000  23499.338920  22879.00  23256.431307
# 4     2022-07-31  BTC/USD  23640.267907  24211.000000  23233.00  23294.000000
# ...          ...      ...           ...           ...       ...           ...
# 2729  2015-02-13  BTC/USD    222.390000    241.760000    221.46    236.000000
# 2730  2015-02-12  BTC/USD    219.190000    223.200000    217.87    222.600000
# 2731  2015-02-11  BTC/USD    220.960000    224.400000    218.10    219.190000
# 2732  2015-02-10  BTC/USD    220.610000    223.880000    214.00    220.960000
# 2733  2015-02-09  BTC/USD    224.220000    225.000000    215.40    220.610000
#
#         Volume USD    Volume BTC
# ...

# %%
mycrypto = []
i = 0
for each in all_coins:
