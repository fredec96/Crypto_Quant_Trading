# %%
# Initial Imports
import os
import glob
import pandas as pd

# %% [markdown]
# # Import and Format CSV data
#
# * This part of the file imports and formats all of the uncleaned CSV files contained in the Raw_CSV directory
# * Python [Glob](https://docs.python.org/3/library/glob.html) library was used to find all CSV pathnames
# * We should be able to do all analysis using this file and the dictionary of DataFrames
#
# ### Dictionary Format
# * Keys are the three letter ticker symbol with a .csv extension
# * Values are the dataframe
#
# ### Examples
# * Dictionary Key Example: 'BTC.csv'
# * Display BTC.csv dataframe example ```file_dict['BTC.csv'].head()```

# %%
# Format the reading of all files in raw_csv folder
path = 'raw_csv/'
extension = 'csv'
os.chdir(path)
files = glob.glob('*.{}'.format(extension))

# %%
# Read all csv files as a DataFrame and add them to file_dict
file_dict = {}

# Loop to read each CSV, format as DataFrame, and add to file_dict
for file in files:
  key = file
  df = pd.read_csv(file, header=1, infer_datetime_format=True, parse_dates=True).set_index('date') 
  
  file_dict[key] = df

    
#Old Attempts at formatting the Dataframe from CSV 
    #df = pd.read_csv(file, index=date, header=1).set_index('date')
    #usecols = ['date', 'open', 'high', 'low', 'close' 'Volume USD']
    
    # Set time column to date time
    # df['date'] = pd.to_datetime(df['date'])
    
    # Set time column to index
    # df = df.set_index('date')

# %%
# This loop runs without error but doesnt do what it's supposed to

# Loop through dataframes in dictionary to include only select columns
for df in file_dict.values():
    df = df[['open', 'high', 'low', 'close', 'Volume USD']]

# %%
# Display first five and last five rows of BTC.csv dataframe
file_dict['BTC.csv']
# Out:
#                               unix   symbol          open          high  \
# date
# 2022-08-04 00:00:00  1659571200000  BTC/USD  22813.213072  23006.000000
# 2022-08-03 00:00:00  1659484800000  BTC/USD  22982.000000  23634.097482
# 2022-08-02 00:00:00  1659398400000  BTC/USD  23256.000000  23466.000000
# 2022-08-01 00:00:00  1659312000000  BTC/USD  23291.000000  23499.338920
# 2022-07-31 00:00:00  1659225600000  BTC/USD  23640.267907  24211.000000
# ...                            ...      ...           ...           ...
# 2015-02-13 00:00:00     1423785600  BTC/USD    222.390000    241.760000
# 2015-02-12 00:00:00     1423699200  BTC/USD    219.190000    223.200000
# 2015-02-11 00:00:00     1423612800  BTC/USD    220.960000    224.400000
# 2015-02-10 00:00:00     1423526400  BTC/USD    220.610000    223.880000
# 2015-02-09 00:00:00     1423440000  BTC/USD    224.220000    225.000000
#
#                           low         close    Volume USD    Volume BTC
# date
# 2022-08-04 00:00:00  22792.00  22969.000000  1.247936e+06     54.331300
# 2022-08-03 00:00:00  22680.00  22813.873707  1.083055e+08   4747.351281
# 2022-08-02 00:00:00  22676.00  22986.000000  9.698831e+07   4219.451219
# 2022-08-01 00:00:00  22879.00  23256.431307  1.297409e+08   5578.709695
# 2022-07-31 00:00:00  23233.00  23294.000000  7.329680e+07   3146.595788
# ...                       ...           ...           ...           ...
# 2015-02-13 00:00:00    221.46    236.000000  6.806973e+06  29079.110000
# 2015-02-12 00:00:00    217.87    222.600000  2.468883e+06  11190.650000
# 2015-02-11 00:00:00    218.10    219.190000  4.268987e+06  19289.280000
# 2015-02-10 00:00:00    214.00    220.960000  6.402351e+06  29268.950000
# 2015-02-09 00:00:00    215.40    220.610000  6.493501e+06  29625.030000
#
# [2734 rows x 8 columns]

# %%
# Display BTC.csv dataframe data types
file_dict['BTC.csv'].dtypes
# Out:
# unix            int64
# symbol         object
# open          float64
# high          float64
# low           float64
# close         float64
# Volume USD    float64
# Volume BTC    float64
# dtype: object
